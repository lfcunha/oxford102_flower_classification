# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
os.getcwd()
# Out:
# '/home/ubuntu'

# %%
os.listdir("/efs/fgvc2018-flower/train/category_11")
# Out:
# ['471885.jpg',
#  '10277.jpg',
#  '9789.jpg',
#  '479805.jpg',
#  '10358.jpg',
#  '10196.jpg',
#  '10079.jpg',
#  '479049.jpg',
#  '478158.jpg',
#  '9987.jpg',
#  '10000.jpg',
#  '520631.jpg',
#  '10394.jpg',
#  '539556.jpg',
#  '513897.jpg',
#  '513800.jpg',
#  '673827.jpg',
#  '493845.jpg',
#  '654396.jpg',
#  '10295.jpg',
#  '9969.jpg',
#  '472794.jpg',
#  '490220.jpg',
#  '10376.jpg',
#  '9888.jpg',
#  '478932.jpg',
#  '619728.jpg',
#  '497526.jpg',
#  '10259.jpg',
#  '520172.jpg',
#  '10097.jpg',
#  '460700.jpg',
#  '10178.jpg',
#  '498651.jpg',
#  '655755.jpg',
#  '542060.jpg',
#  '470213.jpg',
#  '9800.jpg',
#  '10286.jpg',
#  '9798.jpg',
#  '491496.jpg',
#  '518955.jpg',
#  '499173.jpg',
#  '9879.jpg',
#  '10367.jpg',
#  '520442.jpg',
#  '455496.jpg',
#  '475971.jpg',
#  '10088.jpg',
#  '10169.jpg',
#  '540161.jpg',
#  '475818.jpg',
#  '9996.jpg',
#  '527982.jpg',
#  '457179.jpg',
#  '537369.jpg',
#  '9978.jpg',
#  '10385.jpg',
#  '9897.jpg',
#  '10268.jpg',
#  '518775.jpg',
# ...

# %%
# %matplotlib inline
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:278: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
img=mpimg.imread('/efs/fgvc2018-flower/train/category_11/520774.jpg')
imgplot = plt.imshow(img)
