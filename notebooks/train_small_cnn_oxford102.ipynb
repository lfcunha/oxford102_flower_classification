# %%
import keras
from keras import applications
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers
from keras.models import Sequential, Model 
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D
from keras import backend as k 
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import os

import tensorflow
from time import time

# %% [markdown]
# # Data Augmentation

# %%
datagen = ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest')

# %%
img = load_img('/data/oxford102/jpg/image_00001.jpg')  # this is a PIL image
x = img_to_array(img)  # this is a Numpy array with shape (3, 150, 150)
x = x.reshape((1,) + x.shape)  # this is a Numpy array with shape (1, 3, 150, 150)

# the .flow() command below generates batches of randomly transformed images
# and saves the results to the `preview/` directory
i = 0
for batch in datagen.flow(x, batch_size=1,
                          save_to_dir='preview', save_prefix='flower', save_format='jpeg'):
    i += 1
    if i > 20:
        break  # otherwise the generator would loop indefinitely

# %%
category = "/data/preview/"
imgs = np.random.choice(os.listdir(category), size=20, replace=False)
#os.listdir(category)

w=10
h=10
fig=plt.figure(figsize=(12, 12))
columns = 4
rows = 5
for i in range(1, columns*rows +1):
    #img = np.random.randint(10, size=(h,w))
    fig.add_subplot(rows, columns, i)
    img=mpimg.imread(category + imgs[i-1])
    imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# # Train small convnet

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense

model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(150, 150, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# %%
model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(102, activation="softmax"))
#model.add(Activation('sigmoid'))


# #Adding custom Layers 
# x = model.output
# x = Flatten()(x)
# x = Dense(1024, activation="relu")(x)
# x = Dropout(0.5)(x)
# #x = Dense(1024, activation="relu")(x)
# predictions = Dense(nr_categories, activation="softmax")(x)



model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop', 
              #optimizer=optimizers.SGD(lr=0.0001, momentum=0.9),
              metrics=['accuracy'])

#model_final.compile(loss = "categorical_crossentropy", optimizer = optimizers.SGD(lr=0.0001, momentum=0.9), metrics=["accuracy"])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# activation_9 (Activation)    (None, 148, 148, 32)      0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 72, 72, 32)        9248
# _________________________________________________________________
# activation_10 (Activation)   (None, 72, 72, 32)        0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 34, 34, 64)        18496
# _________________________________________________________________
# activation_11 (Activation)   (None, 34, 34, 64)        0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 18496)             0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               4735232
# _________________________________________________________________
# activation_12 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 102)               26214
# =================================================================
# Total params: 4,790,086
# Trainable params: 4,790,086
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 16

# this is the augmentation configuration we will use for training
# train_datagen = ImageDataGenerator(
#         rescale=1./255,
#         shear_range=0.2,
#         zoom_range=0.2,
#         horizontal_flip=True)
train_datagen = ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest')

# this is the augmentation configuration we will use for testing:
# only rescaling
test_datagen = ImageDataGenerator(rescale=1./255)

# this is a generator that will read pictures found in
# subfolers of 'data/train', and indefinitely generate
# batches of augmented image data
train_generator = train_datagen.flow_from_directory(
        '/data/oxford102/train',  # this is the target directory
        target_size=(150, 150),  # all images will be resized to 150x150
        batch_size=batch_size,
        class_mode='categorical')  # since we use binary_crossentropy loss, we need binary labels

# this is a similar generator, for validation data
validation_generator = test_datagen.flow_from_directory(
        '/data/oxford102/val',
        target_size=(150, 150),
        batch_size=batch_size,
        class_mode='categorical')
# Out:
# Found 5698 images belonging to 102 classes.
# Found 2441 images belonging to 102 classes.

# %%
checkpoint = ModelCheckpoint("/data/oxford102/small_convnet_rmsprop.h5", monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
early = EarlyStopping(monitor='val_acc', min_delta=0, patience=5, verbose=1, mode='auto')
tensorboard = TensorBoard(log_dir="logs/{}".format(time()), histogram_freq=0, write_graph=True, write_images=True)

# %%
model.fit_generator(
        train_generator,
        steps_per_epoch=5698 // batch_size,
        epochs=50,
        validation_data=validation_generator,
        validation_steps=2441 // batch_size,
        callbacks = [checkpoint, early, tensorboard])
#model.save_weights('first_try.h5')  # always save your weights after training or during training
# Out:
# Epoch 1/50
# 356/356 [==============================] - 129s 362ms/step - loss: 4.1382 - acc: 0.0755 - val_loss: 3.5624 - val_acc: 0.1591
#
# Epoch 00001: val_acc improved from -inf to 0.15913, saving model to vgg16_all_p2.h5
# Epoch 2/50
# 356/356 [==============================] - 114s 320ms/step - loss: 3.4829 - acc: 0.1606 - val_loss: 3.0388 - val_acc: 0.2549
#
# Epoch 00002: val_acc improved from 0.15913 to 0.25493, saving model to vgg16_all_p2.h5
# Epoch 3/50
# 356/356 [==============================] - 114s 320ms/step - loss: 3.0876 - acc: 0.2428 - val_loss: 2.7426 - val_acc: 0.3059
#
# Epoch 00003: val_acc improved from 0.25493 to 0.30592, saving model to vgg16_all_p2.h5
# Epoch 4/50
# 356/356 [==============================] - 115s 324ms/step - loss: 2.8135 - acc: 0.2995 - val_loss: 2.5834 - val_acc: 0.3544
#
# Epoch 00004: val_acc improved from 0.30592 to 0.35444, saving model to vgg16_all_p2.h5
# Epoch 5/50
# 356/356 [==============================] - 114s 320ms/step - loss: 2.5756 - acc: 0.3436 - val_loss: 2.4258 - val_acc: 0.3923
#
# Epoch 00005: val_acc improved from 0.35444 to 0.39227, saving model to vgg16_all_p2.h5
# Epoch 6/50
# 356/356 [==============================] - 114s 319ms/step - loss: 2.4191 - acc: 0.3768 - val_loss: 2.3786 - val_acc: 0.4334
#
# Epoch 00006: val_acc improved from 0.39227 to 0.43339, saving model to vgg16_all_p2.h5
# Epoch 7/50
# 356/356 [==============================] - 113s 317ms/step - loss: 2.2614 - acc: 0.4149 - val_loss: 2.1758 - val_acc: 0.4523
#
# Epoch 00007: val_acc improved from 0.43339 to 0.45230, saving model to vgg16_all_p2.h5
# Epoch 8/50
# 356/356 [==============================] - 113s 318ms/step - loss: 2.1707 - acc: 0.4326 - val_loss: 2.1831 - val_acc: 0.4527
#
# Epoch 00008: val_acc improved from 0.45230 to 0.45271, saving model to vgg16_all_p2.h5
# Epoch 9/50
# 356/356 [==============================] - 114s 320ms/step - loss: 2.0895 - acc: 0.4598 - val_loss: 2.0169 - val_acc: 0.4971
#
# Epoch 00009: val_acc improved from 0.45271 to 0.49712, saving model to vgg16_all_p2.h5
# Epoch 10/50
# 356/356 [==============================] - 113s 316ms/step - loss: 2.0007 - acc: 0.4738 - val_loss: 2.0937 - val_acc: 0.4794
#
# Epoch 00010: val_acc did not improve from 0.49712
# Epoch 11/50
# 356/356 [==============================] - 113s 317ms/step - loss: 1.9581 - acc: 0.4916 - val_loss: 2.0901 - val_acc: 0.5066
#
# Epoch 00011: val_acc improved from 0.49712 to 0.50658, saving model to vgg16_all_p2.h5
# Epoch 12/50
# 356/356 [==============================] - 111s 313ms/step - loss: 1.9129 - acc: 0.5021 - val_loss: 2.4488 - val_acc: 0.4149
#
# Epoch 00012: val_acc did not improve from 0.50658
# Epoch 13/50
# 356/356 [==============================] - 112s 314ms/step - loss: 1.9196 - acc: 0.5021 - val_loss: 2.0724 - val_acc: 0.5058
#
# Epoch 00013: val_acc did not improve from 0.50658
# Epoch 14/50
# 356/356 [==============================] - 111s 312ms/step - loss: 1.8612 - acc: 0.5225 - val_loss: 1.9463 - val_acc: 0.5201
#
# Epoch 00014: val_acc improved from 0.50658 to 0.52015, saving model to vgg16_all_p2.h5
# Epoch 15/50
# 356/356 [==============================] - 111s 313ms/step - loss: 1.8319 - acc: 0.5239 - val_loss: 1.9369 - val_acc: 0.5317
#
# Epoch 00015: val_acc improved from 0.52015 to 0.53166, saving model to vgg16_all_p2.h5
# Epoch 16/50
# 356/356 [==============================] - 112s 313ms/step - loss: 1.8810 - acc: 0.5239 - val_loss: 1.9897 - val_acc: 0.5177
#
# Epoch 00016: val_acc did not improve from 0.53166
# Epoch 17/50
# 356/356 [==============================] - 111s 312ms/step - loss: 1.8360 - acc: 0.5244 - val_loss: 2.0012 - val_acc: 0.5160
#
# Epoch 00017: val_acc did not improve from 0.53166
# Epoch 18/50
# 356/356 [==============================] - 112s 314ms/step - loss: 1.8415 - acc: 0.5365 - val_loss: 2.0508 - val_acc: 0.5025
#
# Epoch 00018: val_acc did not improve from 0.53166
# Epoch 19/50
# 356/356 [==============================] - 112s 315ms/step - loss: 1.8510 - acc: 0.5342 - val_loss: 2.3701 - val_acc: 0.5275
#
# Epoch 00019: val_acc did not improve from 0.53166
# Epoch 20/50
# 356/356 [==============================] - 111s 313ms/step - loss: 1.8705 - acc: 0.5186 - val_loss: 2.1436 - val_acc: 0.4799
#
# Epoch 00020: val_acc did not improve from 0.53166
# Epoch 00020: early stopping

# %% [markdown]
# # optimizer=SGD

# %%
checkpoint = ModelCheckpoint("/data/oxford102/small_convnet_sgd.h5", monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
early = EarlyStopping(monitor='val_acc', min_delta=0, patience=5, verbose=1, mode='auto')
tensorboard = TensorBoard(log_dir="logs/{}".format(time()), histogram_freq=0, write_graph=True, write_images=True)

# %%
model.fit_generator(
        train_generator,
        steps_per_epoch=5698 // batch_size,
        epochs=50,
        validation_data=validation_generator,
        validation_steps=2441 // batch_size,
        callbacks = [checkpoint, early, tensorboard])
#model.save_weights('first_try.h5')  # always save your weights after training or during training
# Out:
# Epoch 1/50
# 356/356 [==============================] - 114s 320ms/step - loss: 4.6108 - acc: 0.0170 - val_loss: 4.5910 - val_acc: 0.0189
#
# Epoch 00001: val_acc improved from -inf to 0.01891, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 2/50
# 356/356 [==============================] - 114s 320ms/step - loss: 4.5813 - acc: 0.0242 - val_loss: 4.5587 - val_acc: 0.0362
#
# Epoch 00002: val_acc improved from 0.01891 to 0.03618, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 3/50
# 356/356 [==============================] - 114s 319ms/step - loss: 4.5638 - acc: 0.0251 - val_loss: 4.5389 - val_acc: 0.0354
#
# Epoch 00003: val_acc did not improve from 0.03618
# Epoch 4/50
# 356/356 [==============================] - 114s 320ms/step - loss: 4.5526 - acc: 0.0270 - val_loss: 4.5243 - val_acc: 0.0329
#
# Epoch 00004: val_acc did not improve from 0.03618
# Epoch 5/50
# 356/356 [==============================] - 114s 319ms/step - loss: 4.5374 - acc: 0.0297 - val_loss: 4.5045 - val_acc: 0.0391
#
# Epoch 00005: val_acc improved from 0.03618 to 0.03906, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 6/50
# 356/356 [==============================] - 113s 318ms/step - loss: 4.5196 - acc: 0.0351 - val_loss: 4.4791 - val_acc: 0.0584
#
# Epoch 00006: val_acc improved from 0.03906 to 0.05839, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 7/50
# 356/356 [==============================] - 113s 317ms/step - loss: 4.4941 - acc: 0.0397 - val_loss: 4.4449 - val_acc: 0.0666
#
# Epoch 00007: val_acc improved from 0.05839 to 0.06661, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 8/50
# 356/356 [==============================] - 112s 315ms/step - loss: 4.4637 - acc: 0.0481 - val_loss: 4.3984 - val_acc: 0.0691
#
# Epoch 00008: val_acc improved from 0.06661 to 0.06908, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 9/50
# 356/356 [==============================] - 113s 317ms/step - loss: 4.4092 - acc: 0.0578 - val_loss: 4.3382 - val_acc: 0.0670
#
# Epoch 00009: val_acc did not improve from 0.06908
# Epoch 10/50
# 356/356 [==============================] - 113s 317ms/step - loss: 4.3731 - acc: 0.0581 - val_loss: 4.2823 - val_acc: 0.0785
#
# Epoch 00010: val_acc improved from 0.06908 to 0.07854, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 11/50
# 356/356 [==============================] - 113s 317ms/step - loss: 4.3136 - acc: 0.0578 - val_loss: 4.2259 - val_acc: 0.0802
#
# Epoch 00011: val_acc improved from 0.07854 to 0.08018, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 12/50
# 356/356 [==============================] - 114s 319ms/step - loss: 4.2567 - acc: 0.0641 - val_loss: 4.1553 - val_acc: 0.0794
#
# Epoch 00012: val_acc did not improve from 0.08018
# Epoch 13/50
# 356/356 [==============================] - 113s 316ms/step - loss: 4.2156 - acc: 0.0662 - val_loss: 4.0897 - val_acc: 0.0905
#
# Epoch 00013: val_acc improved from 0.08018 to 0.09046, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 14/50
# 356/356 [==============================] - 112s 315ms/step - loss: 4.1623 - acc: 0.0730 - val_loss: 4.0385 - val_acc: 0.0958
#
# Epoch 00014: val_acc improved from 0.09046 to 0.09581, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 15/50
# 356/356 [==============================] - 111s 313ms/step - loss: 4.1174 - acc: 0.0830 - val_loss: 3.9819 - val_acc: 0.1086
#
# Epoch 00015: val_acc improved from 0.09581 to 0.10855, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 16/50
# 356/356 [==============================] - 112s 314ms/step - loss: 4.0771 - acc: 0.0867 - val_loss: 3.9277 - val_acc: 0.1139
#
# Epoch 00016: val_acc improved from 0.10855 to 0.11390, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 17/50
# 356/356 [==============================] - 112s 314ms/step - loss: 4.0129 - acc: 0.0938 - val_loss: 3.8759 - val_acc: 0.1283
#
# Epoch 00017: val_acc improved from 0.11390 to 0.12829, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 18/50
# 356/356 [==============================] - 112s 314ms/step - loss: 3.9695 - acc: 0.1022 - val_loss: 3.8023 - val_acc: 0.1419
#
# Epoch 00018: val_acc improved from 0.12829 to 0.14186, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 19/50
# 356/356 [==============================] - 113s 318ms/step - loss: 3.8956 - acc: 0.1118 - val_loss: 3.7466 - val_acc: 0.1501
#
# Epoch 00019: val_acc improved from 0.14186 to 0.15008, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 20/50
# 356/356 [==============================] - 112s 315ms/step - loss: 3.8657 - acc: 0.1111 - val_loss: 3.7043 - val_acc: 0.1534
#
# Epoch 00020: val_acc improved from 0.15008 to 0.15337, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 21/50
# 356/356 [==============================] - 113s 318ms/step - loss: 3.8131 - acc: 0.1171 - val_loss: 3.6460 - val_acc: 0.1669
#
# Epoch 00021: val_acc improved from 0.15337 to 0.16694, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 22/50
# 356/356 [==============================] - 112s 315ms/step - loss: 3.7831 - acc: 0.1203 - val_loss: 3.6018 - val_acc: 0.1682
#
# Epoch 00022: val_acc improved from 0.16694 to 0.16817, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 23/50
# 356/356 [==============================] - 112s 314ms/step - loss: 3.7231 - acc: 0.1333 - val_loss: 3.5373 - val_acc: 0.1731
#
# Epoch 00023: val_acc improved from 0.16817 to 0.17311, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 24/50
# 356/356 [==============================] - 112s 314ms/step - loss: 3.6760 - acc: 0.1320 - val_loss: 3.5069 - val_acc: 0.1904
#
# Epoch 00024: val_acc improved from 0.17311 to 0.19038, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 25/50
# 356/356 [==============================] - 111s 313ms/step - loss: 3.6430 - acc: 0.1475 - val_loss: 3.4671 - val_acc: 0.1994
#
# Epoch 00025: val_acc improved from 0.19038 to 0.19942, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 26/50
# 356/356 [==============================] - 113s 316ms/step - loss: 3.5868 - acc: 0.1589 - val_loss: 3.4147 - val_acc: 0.2015
#
# Epoch 00026: val_acc improved from 0.19942 to 0.20148, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 27/50
# 356/356 [==============================] - 112s 314ms/step - loss: 3.5664 - acc: 0.1554 - val_loss: 3.3768 - val_acc: 0.2188
#
# Epoch 00027: val_acc improved from 0.20148 to 0.21875, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 28/50
# 356/356 [==============================] - 112s 315ms/step - loss: 3.5211 - acc: 0.1657 - val_loss: 3.3426 - val_acc: 0.2089
#
# Epoch 00028: val_acc did not improve from 0.21875
# Epoch 29/50
# 356/356 [==============================] - 112s 314ms/step - loss: 3.4954 - acc: 0.1634 - val_loss: 3.2933 - val_acc: 0.2257
#
# Epoch 00029: val_acc improved from 0.21875 to 0.22574, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 30/50
# 356/356 [==============================] - 111s 313ms/step - loss: 3.4418 - acc: 0.1803 - val_loss: 3.2465 - val_acc: 0.2299
#
# Epoch 00030: val_acc improved from 0.22574 to 0.22985, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 31/50
# 356/356 [==============================] - 113s 318ms/step - loss: 3.3916 - acc: 0.1814 - val_loss: 3.2045 - val_acc: 0.2253
#
# Epoch 00031: val_acc did not improve from 0.22985
# Epoch 32/50
# 356/356 [==============================] - 111s 312ms/step - loss: 3.3760 - acc: 0.1873 - val_loss: 3.1867 - val_acc: 0.2336
#
# Epoch 00032: val_acc improved from 0.22985 to 0.23355, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 33/50
# 356/356 [==============================] - 112s 314ms/step - loss: 3.3524 - acc: 0.1896 - val_loss: 3.1587 - val_acc: 0.2471
#
# Epoch 00033: val_acc improved from 0.23355 to 0.24712, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 34/50
# 356/356 [==============================] - 112s 316ms/step - loss: 3.2936 - acc: 0.2008 - val_loss: 3.1244 - val_acc: 0.2438
#
# Epoch 00034: val_acc did not improve from 0.24712
# Epoch 35/50
# 356/356 [==============================] - 111s 313ms/step - loss: 3.2592 - acc: 0.2066 - val_loss: 3.0739 - val_acc: 0.2545
#
# Epoch 00035: val_acc improved from 0.24712 to 0.25452, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 36/50
# 356/356 [==============================] - 113s 319ms/step - loss: 3.2517 - acc: 0.1984 - val_loss: 3.0567 - val_acc: 0.2562
#
# Epoch 00036: val_acc improved from 0.25452 to 0.25617, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 37/50
# 356/356 [==============================] - 112s 315ms/step - loss: 3.1939 - acc: 0.2214 - val_loss: 3.0105 - val_acc: 0.2599
#
# Epoch 00037: val_acc improved from 0.25617 to 0.25987, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 38/50
# 356/356 [==============================] - 112s 313ms/step - loss: 3.1559 - acc: 0.2221 - val_loss: 2.9975 - val_acc: 0.2627
#
# Epoch 00038: val_acc improved from 0.25987 to 0.26275, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 39/50
# 356/356 [==============================] - 111s 311ms/step - loss: 3.1410 - acc: 0.2323 - val_loss: 2.9733 - val_acc: 0.2854
#
# Epoch 00039: val_acc improved from 0.26275 to 0.28536, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 40/50
# 356/356 [==============================] - 111s 311ms/step - loss: 3.1107 - acc: 0.2289 - val_loss: 2.9398 - val_acc: 0.2858
#
# Epoch 00040: val_acc improved from 0.28536 to 0.28577, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 41/50
# 356/356 [==============================] - 112s 314ms/step - loss: 3.0964 - acc: 0.2379 - val_loss: 2.9368 - val_acc: 0.2796
#
# Epoch 00041: val_acc did not improve from 0.28577
# Epoch 42/50
# 356/356 [==============================] - 111s 313ms/step - loss: 3.0629 - acc: 0.2372 - val_loss: 2.9081 - val_acc: 0.2981
#
# Epoch 00042: val_acc improved from 0.28577 to 0.29811, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 43/50
# 356/356 [==============================] - 111s 312ms/step - loss: 3.0303 - acc: 0.2526 - val_loss: 2.8992 - val_acc: 0.2989
#
# Epoch 00043: val_acc improved from 0.29811 to 0.29893, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 44/50
# 356/356 [==============================] - 111s 312ms/step - loss: 3.0249 - acc: 0.2481 - val_loss: 2.8739 - val_acc: 0.3022
#
# Epoch 00044: val_acc improved from 0.29893 to 0.30222, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 45/50
# 356/356 [==============================] - 111s 313ms/step - loss: 2.9730 - acc: 0.2604 - val_loss: 2.8457 - val_acc: 0.3002
#
# Epoch 00045: val_acc did not improve from 0.30222
# Epoch 46/50
# 356/356 [==============================] - 113s 317ms/step - loss: 2.9402 - acc: 0.2658 - val_loss: 2.8076 - val_acc: 0.3125
#
# Epoch 00046: val_acc improved from 0.30222 to 0.31250, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 47/50
# 356/356 [==============================] - 112s 314ms/step - loss: 2.9511 - acc: 0.2649 - val_loss: 2.7950 - val_acc: 0.3154
#
# Epoch 00047: val_acc improved from 0.31250 to 0.31538, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 48/50
# 356/356 [==============================] - 112s 314ms/step - loss: 2.8949 - acc: 0.2753 - val_loss: 2.7885 - val_acc: 0.3195
#
# Epoch 00048: val_acc improved from 0.31538 to 0.31949, saving model to /data/oxford102/small_convnet_sgd.h5
# Epoch 49/50
# 356/356 [==============================] - 111s 312ms/step - loss: 2.8814 - acc: 0.2730 - val_loss: 2.7427 - val_acc: 0.3187
#
# Epoch 00049: val_acc did not improve from 0.31949
# Epoch 50/50
# 356/356 [==============================] - 111s 313ms/step - loss: 2.8388 - acc: 0.2814 - val_loss: 2.7387 - val_acc: 0.3203
#
# Epoch 00050: val_acc improved from 0.31949 to 0.32031, saving model to /data/oxford102/small_convnet_sgd.h5

# %% [markdown]
# # With Data augmentation

# %%
checkpoint = ModelCheckpoint("/data/oxford102/small_convnet_rmsprop_more_augmentation.h5", monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
early = EarlyStopping(monitor='val_acc', min_delta=0, patience=5, verbose=1, mode='auto')
tensorboard = TensorBoard(log_dir="logs/{}".format(time()), histogram_freq=0, write_graph=True, write_images=True)
model.fit_generator(
        train_generator,
        steps_per_epoch=5698 // batch_size,
        epochs=50,
        validation_data=validation_generator,
        validation_steps=2441 // batch_size,
        callbacks = [checkpoint, early, tensorboard])
#model.save_weights('first_try.h5')  # always save your weights after training or during training
# Out:
# Epoch 1/50
# 356/356 [==============================] - 115s 323ms/step - loss: 4.2427 - acc: 0.0620 - val_loss: 3.7434 - val_acc: 0.1172
#
# Epoch 00001: val_acc improved from -inf to 0.11719, saving model to /data/oxford102/small_convnet_rmsprop_more_augmentation.h5
# Epoch 2/50
# 356/356 [==============================] - 115s 324ms/step - loss: 3.6455 - acc: 0.1178 - val_loss: 3.2986 - val_acc: 0.1945
#
# Epoch 00002: val_acc improved from 0.11719 to 0.19449, saving model to /data/oxford102/small_convnet_rmsprop_more_augmentation.h5
# Epoch 3/50
# 356/356 [==============================] - 115s 322ms/step - loss: 3.3467 - acc: 0.1733 - val_loss: 3.0784 - val_acc: 0.2484
#
# Epoch 00003: val_acc improved from 0.19449 to 0.24836, saving model to /data/oxford102/small_convnet_rmsprop_more_augmentation.h5
# Epoch 4/50
# 356/356 [==============================] - 115s 322ms/step - loss: 3.1507 - acc: 0.2242 - val_loss: 3.4569 - val_acc: 0.2270
#
# Epoch 00004: val_acc did not improve from 0.24836
# Epoch 5/50
# 356/356 [==============================] - 115s 323ms/step - loss: 3.0069 - acc: 0.2446 - val_loss: 3.0476 - val_acc: 0.2887
#
# Epoch 00005: val_acc improved from 0.24836 to 0.28865, saving model to /data/oxford102/small_convnet_rmsprop_more_augmentation.h5
# Epoch 6/50
# 356/356 [==============================] - 114s 321ms/step - loss: 2.9140 - acc: 0.2753 - val_loss: 2.6122 - val_acc: 0.3499
#
# Epoch 00006: val_acc improved from 0.28865 to 0.34992, saving model to /data/oxford102/small_convnet_rmsprop_more_augmentation.h5
# Epoch 7/50
# 356/356 [==============================] - 114s 319ms/step - loss: 2.8304 - acc: 0.2897 - val_loss: 2.6918 - val_acc: 0.3540
#
# Epoch 00007: val_acc improved from 0.34992 to 0.35403, saving model to /data/oxford102/small_convnet_rmsprop_more_augmentation.h5
# Epoch 8/50
# 356/356 [==============================] - 113s 319ms/step - loss: 2.7620 - acc: 0.2986 - val_loss: 2.4860 - val_acc: 0.3877
#
# Epoch 00008: val_acc improved from 0.35403 to 0.38775, saving model to /data/oxford102/small_convnet_rmsprop_more_augmentation.h5
# Epoch 9/50
# 356/356 [==============================] - 114s 319ms/step - loss: 2.7064 - acc: 0.3076 - val_loss: 2.6164 - val_acc: 0.3565
#
# Epoch 00009: val_acc did not improve from 0.38775
# Epoch 10/50
# 356/356 [==============================] - 114s 321ms/step - loss: 2.6828 - acc: 0.3193 - val_loss: 2.3599 - val_acc: 0.4100
#
# Epoch 00010: val_acc improved from 0.38775 to 0.40995, saving model to /data/oxford102/small_convnet_rmsprop_more_augmentation.h5
# Epoch 11/50
# 356/356 [==============================] - 114s 321ms/step - loss: 2.6567 - acc: 0.3230 - val_loss: 2.3180 - val_acc: 0.4350
#
# Epoch 00011: val_acc improved from 0.40995 to 0.43503, saving model to /data/oxford102/small_convnet_rmsprop_more_augmentation.h5
# Epoch 12/50
# 356/356 [==============================] - 113s 317ms/step - loss: 2.6199 - acc: 0.3369 - val_loss: 2.4607 - val_acc: 0.4042
#
# Epoch 00012: val_acc did not improve from 0.43503
# Epoch 13/50
# 356/356 [==============================] - 112s 315ms/step - loss: 2.5943 - acc: 0.3401 - val_loss: 2.5311 - val_acc: 0.3783
#
# Epoch 00013: val_acc did not improve from 0.43503
# Epoch 14/50
# 356/356 [==============================] - 113s 317ms/step - loss: 2.5536 - acc: 0.3531 - val_loss: 2.3109 - val_acc: 0.4367
#
# Epoch 00014: val_acc improved from 0.43503 to 0.43668, saving model to /data/oxford102/small_convnet_rmsprop_more_augmentation.h5
# Epoch 15/50
# 356/356 [==============================] - 113s 318ms/step - loss: 2.5277 - acc: 0.3516 - val_loss: 2.3269 - val_acc: 0.4338
#
# Epoch 00015: val_acc did not improve from 0.43668
# Epoch 16/50
# 356/356 [==============================] - 112s 315ms/step - loss: 2.5414 - acc: 0.3552 - val_loss: 2.6906 - val_acc: 0.4067
#
# Epoch 00016: val_acc did not improve from 0.43668
# Epoch 17/50
# 356/356 [==============================] - 113s 317ms/step - loss: 2.5042 - acc: 0.3639 - val_loss: 2.3602 - val_acc: 0.4424
#
# Epoch 00017: val_acc improved from 0.43668 to 0.44243, saving model to /data/oxford102/small_convnet_rmsprop_more_augmentation.h5
# Epoch 18/50
# 356/356 [==============================] - 112s 315ms/step - loss: 2.5659 - acc: 0.3571 - val_loss: 2.4196 - val_acc: 0.4178
#
# Epoch 00018: val_acc did not improve from 0.44243
# Epoch 19/50
# 356/356 [==============================] - 113s 317ms/step - loss: 2.5278 - acc: 0.3576 - val_loss: 2.5375 - val_acc: 0.4042
#
# Epoch 00019: val_acc did not improve from 0.44243
# Epoch 20/50
# 356/356 [==============================] - 112s 316ms/step - loss: 2.5542 - acc: 0.3571 - val_loss: 2.4826 - val_acc: 0.4363
#
# Epoch 00020: val_acc did not improve from 0.44243
# Epoch 21/50
# 356/356 [==============================] - 112s 314ms/step - loss: 2.6130 - acc: 0.3492 - val_loss: 3.8507 - val_acc: 0.2566
#
# Epoch 00021: val_acc did not improve from 0.44243
# Epoch 22/50
# 356/356 [==============================] - 113s 317ms/step - loss: 2.6307 - acc: 0.3497 - val_loss: 2.5435 - val_acc: 0.3845
#
# Epoch 00022: val_acc did not improve from 0.44243
# Epoch 00022: early stopping
